# %%
import pandas as pd
import csv
import re
import io 
import string
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from nltk.stem.snowball import SnowballStemmer
import nltk
nltk.download("stopwords")
nltk.download('punkt')
snowBallStemmer = SnowballStemmer("english")
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
name = "Train"

# %%
dataset = pd.read_csv('/content/Train.txt', sep='\t', header=None)


b=[]
a=[]
x=[]

for i in range(len(dataset)):
    if dataset[0][i]=="meta":
        c = " ".join(a)
        b.append(c)
        a=[]
        x=[]
    elif dataset[0][i]=="@":
        continue
    elif dataset[0][i-1] =="@":
        continue
    else:
        a.append(str(dataset[0][i]))
b.append(" ".join(a))
b.pop(0)

d=[]

for i in range(len(b)):
    if re.search("http[.]*",b[i])!=None:
        b[i]=b[i][:re.search("http[.]*",b[i]).span()[0]]
    else:
        continue

# %%
punct =['RT','_','.','…','...','!','#','__','___','____','_____','..','....','.....','.…','.....','@___','@_','.........','.......','((','(((','—…','........',"'",',','|','?','!','......','!!','??','…',' ................','.....................…','’']
u = ['ðŸ™ðŸŒ¹','ðŸ™ðŸŒ¹','Â´','ðŸ˜ðŸ˜ðŸ˜','?ðŸ˜‚ðŸ˜‚ðŸ˜‚','##','#à¤šà¤®à¥à¤ªà¤¾à¤°à¤£','ðŸŽ‚ðŸ™â¤ï¸','ðŸ','ðŸ’ƒ','ðŸ¤®','â¤+ðŸ”¨=ðŸ’”','ÙˆØ±Ø¯ÛŒ','#êµ¬ë…¸','ðŸ˜­ðŸ’–ðŸ’–','â¤â¤â¤','ðŸŽ‚','ðŸ–ðŸ½','â¤','ðŸ˜ðŸ‘ðŸ’','..ðŸ™‡â€â™€ï¸','ðŸ˜€ðŸ˜€ðŸ˜€ðŸ˜€ðŸ˜…ðŸ˜€ðŸ˜…ðŸ˜€ðŸ˜…','ðŸ˜ðŸ˜','ðŸ‘ŽðŸ–ðŸ‡µðŸ‡°','ðŸ§¡','ðŸ˜©â¤ï¸','ðŸŽŸ','ðŸ¤—ðŸ¤—ðŸ¤—ðŸ’ðŸ’','ðŸ™ðŸ™‚','ðŸ”¥ðŸ”¥','ðŸ†','ðŸŒ´','ðŸ’¯','ðŸ˜ª','à¤¬à¤¹à¥à¤¤','ðŸ‘¶','ðŸ‘‡ðŸ‘‡','ðŸŽ§','ã…‹ã…‹ã…‹ã…‹','âœ¨','ðŸ¤­ðŸ¤­','ðŸ˜¡ðŸ¤¬ðŸ¤¬','Ø¯Ú¾Ø´ØªÚ¯Ø±Ø¯ÛŒ','ðŸ‘‰','ðŸ˜€ðŸ˜€','â€¢','.â€¦','â™¥ï¸â™¥ï¸','ðŸŒº','ðŸŒ¸ðŸ–¤ðŸ’¥','â†‘','ðŸ˜ðŸ’›','ðŸ’œâ¤','~ðŸ™','..ðŸ˜‚ðŸ˜‚','ðŸ’™','ðŸ’«ðŸ’«','ðŸ™â¤ï¸â€¦','ðŸ’ª','ë°¤ë°”ëžŒ','~','Ã','ðŸ’•ðŸ’«','ðŸ‘‡','ðŸ˜‚ðŸ˜‚ðŸ˜¤','à¤¬à¤§à¤¾à¤ˆ','ðŸ˜‚','...â˜ï¸â˜ï¸','ðŸ¤ðŸ˜Ÿ','ðŸ¤”','ðŸ˜˜ðŸ˜˜ðŸ˜˜ðŸ˜˜ðŸ˜˜ðŸ˜˜ðŸ˜˜ðŸ˜�
Ÿ˜ðŸ˜ðŸŽ‚ðŸŽðŸŽðŸŽˆðŸŽˆðŸŽ†ðŸŽ†ðŸŽ‰ðŸŽŠðŸ°ðŸ°','.....â¤ðŸ‘ŒðŸ‘ŒðŸ‘ŒðŸ‘ŒðŸ‘ŒðŸ‘Œ','â¤ï¸â¤ï¸â¤ï¸â¤ï¸â¤ï¸â¤ï¸','ðŸ¦¹â€â™‚ï¸','à¤œà¤¾à¤¤à¥€','ðŸ‘','****','ðŸ˜‹','ðŸ‡®ðŸ‡³ðŸ‡®ðŸ‡³ðŸ‡®ðŸ‡³ðŸ‡®ðŸ‡³ðŸ‡®ðŸ‡³','ðŸ˜”ðŸ˜”','ðŸƒ','ðŸ˜†','ðŸ’”','ðŸ˜â€¦','??ðŸ™„','ðŸ˜©ðŸ˜‘','ðŸ‘ðŸ‘ðŸ˜‰ðŸ˜‰','1â€¦','ðŸ˜„','â˜ºâ˜º','à¤¹à¥‹..','ðŸ˜¬ðŸ˜¬..','à¨œà¨¿','ðŸ’“ðŸ’“ðŸ’“ðŸ˜ðŸ˜ðŸ˜','ðŸ¤£ðŸ”¥','ðŸ˜‰ðŸ˜‰ðŸ˜‰','ðŸ˜‘ðŸ˜‘','ÛŒÛ']

def text_data_cleaning(sentence):
    cleaned_tokens = []
    for token in sentence.split(' '):
        if token not in punct:
            cleaned_tokens.append(token)
    return(' '.join(cleaned_tokens))

a=[]
for i in range(len(b)):
    a.append(text_data_cleaning(b[i]))

def text_data_cleaning_1(sentence):
    cleaned_tokens = []
    for token in sentence.split(' '):
        if token not in u:
            cleaned_tokens.append(token)
    return(' '.join(cleaned_tokens))

h=[]
for i in range(len(a)):
       h.append(text_data_cleaning_1(a[i]))

# %%
def rmvsw(example_sent):
  word_tokens = word_tokenize(example_sent)
  filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  filtered_sentence = []   
  for w in word_tokens:
    if w not in stop_words: 
      filtered_sentence.append(w)
  return(' '.join(filtered_sentence))

# %%
def stemming(sentence):
  wordList = nltk.word_tokenize(sentence)
  stemWords = [snowBallStemmer.stem(word) for word in wordList]
  return(' '.join(stemWords))

# %%
X=[]
for i in range(len(h)):
  X.append(stemming(rmvsw(h[i])))

# %%
len(X)
# Out:
# 4534

# %%
def remove_emoji(text):
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
cleaned_sentences = []

for sentence in X:
    cleaned_sentence = remove_emoji(sentence)
    cleaned_sentences.append(cleaned_sentence)

print(cleaned_sentences)
# Out:
# ['', 'pakistan ka ghra tauq pakistan israel ko tasleem nahein kerta isko palestin kehta - occupi palestin nan', 'madarchod mull ye mathura nahi dikha tha jab mullo ne hindu ko iss liy mara ki vo lass ki pais mag liy https // co / oxf8tr3bl nan', 'manya pradhan mantri mahoday shriman narendra modi ji pradhanmantri bann par hardik badhai tahe dil https // co / prnomskkn1 nan', 'krishna jcb full trend chal rahi aa nan', 'loksabha janta sirf modi ko vote de rahi thi na ki kisi mp bjp ko without https // co / shtbwcb7fm nan', 'bhosdik tum pechvad ki tatti hi rahog bc nan', 'love u bhaijan ... ♥♥ father + son bharat iambharat bharatthiseid best pic from entir promot mashallah https // co / s2xhwu6lud nan', 'tumhara pass abh deemagh hai nahi islea googl ko apna deemagh banaya hua hai har koi tumhari tarh https // co / bxueug3xsn nan', 'nolo weni anker gae weekend  nan', 'aimim lage raho mullo tumhr issi quran faad gyan ki kayal hain duniya allah bhi khus https // co / gha9dwnz6u nan', 'omer
# ...

# %%
len(cleaned_sentences)
# Out:
# 4534

# %%
hinstopwords = pd.read_csv('/content/hin.txt', sep="\t", header=None )
hinstopwords = list(hinstopwords[0])[:1000]

# %%
def Hrmvsw(example_sent):
  word_tokens = word_tokenize(example_sent)
  filtered_sentence = [w for w in word_tokens if not w in hinstopwords] 
  filtered_sentence = []   
  for w in word_tokens:
    if w not in stop_words: 
      filtered_sentence.append(w)
  return(' '.join(filtered_sentence))

XX=[]
for i in range(len(X)):
  XX.append(Hrmvsw(X[i]))

# %%
# Out:
# []

# %%
import re

def remove_emoji(text):
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
cleaned_sentences = []

for sentence in XX:
    cleaned_sentence = remove_emoji(sentence)
    cleaned_sentences.append(cleaned_sentence)

print(cleaned_sentences)
# Out:
# ['', 'pakistan ka ghra tauq pakistan israel ko tasleem nahein kerta isko palestin kehta - occupi palestin nan', 'madarchod mull ye mathura nahi dikha tha jab mullo ne hindu ko iss liy mara ki vo lass ki pais mag liy https // co / oxf8tr3bl nan', 'manya pradhan mantri mahoday shriman narendra modi ji pradhanmantri bann par hardik badhai tahe dil https // co / prnomskkn1 nan', 'krishna jcb full trend chal rahi aa nan', 'loksabha janta sirf modi ko vote de rahi thi na ki kisi mp bjp ko without https // co / shtbwcb7fm nan', 'bhosdik tum pechvad ki tatti hi rahog bc nan', 'love u bhaijan ... ♥♥ father + son bharat iambharat bharatthiseid best pic entir promot mashallah https // co / s2xhwu6lud nan', 'tumhara pass abh deemagh hai nahi islea googl ko apna deemagh banaya hua hai har koi tumhari tarh https // co / bxueug3xsn nan', 'nolo weni anker gae weekend  nan', 'aimim lage raho mullo tumhr issi quran faad gyan ki kayal hain duniya allah bhi khus https // co / gha9dwnz6u nan', 'omer muha
# ...

# %%
X2=cleaned_sentences

# %%
sentiment =[]        
for i in range(len(dataset)):
    if dataset[2][i]=='negative':
        sentiment.append(0)
    elif dataset[2][i]=='neutral':
        sentiment.append(1)
    elif dataset[2][i]=='positive':
        sentiment.append(2)

            
uid=[]            
for i in range(len(dataset)):
    if dataset[1][i]!='Eng' and dataset[1][i]!='Hin' and dataset[1][i]!='O' and dataset[1][i]!='EMT' and dataset[1][i]!='nan':
        uid.append(dataset[1][i])          
    else:
        continue

uidd=[]
for i in range(len(uid)):
    if type(uid[i])==str:
        uidd.append(uid[i])

# %%
len(X2)
# Out:
# 4534

# %%
with open("/content/"+name+"V1.tsv", 'wt',encoding="utf-8") as out_file:
    tsv_writer = csv.writer(out_file, delimiter='\t')
    for k in range(len(X)):
        f=[]
        f.append(uidd[k])
        f.append(X[k])
        f.append(sentiment[k])
        tsv_writer.writerow(f)
